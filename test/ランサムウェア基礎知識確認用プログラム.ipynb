# %% [markdown]
# # 暗号化

# %%
! pip install cryptography
from cryptography.fernet import Fernet
# Out:
# Requirement already satisfied: cryptography in d:\anaconda\lib\site-packages (37.0.1)
# Requirement already satisfied: cffi>=1.12 in d:\anaconda\lib\site-packages (from cryptography) (1.15.1)
# Requirement already satisfied: pycparser in d:\anaconda\lib\site-packages (from cffi>=1.12->cryptography) (2.21)

# %%
"""
このコードもローカル必須

.tex 暗号化版

実行はコマンドプロンプトから
.py 推奨
"""

from cryptography.fernet import Fernet
from regex import R

#キーを作成する
key = Fernet.generate_key()

#キーをローカルに保存する
with open(R"C:\Users\student\Desktop\key_data","wb") as key_data:
    key_data.write(key)

#暗号化するファイルの取得
with open(R"C:\Users\student\Desktop\test.txt","r") as file:
    data = file.read()

print("暗号化する前: ",data)

#データをバイトに変換する
byte_data = data.encode()

#Fernetオブジェクトの初期化
f = Fernet(key)

#バイトデータを暗号化する
encrypt_data = f.encrypt(byte_data)

#暗号化した情報をファイルに書き込む
with open(R"C:\Users\student\Desktop\test.txt","wb") as file:
    file.write(encrypt_data)

print("暗号化した後: ", encrypt_data)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7836\1744260416.py in <module>
#      15
#      16 #キーをローカルに保存する
# ---> 17 with open(R"C:\Users\student\Desktop\key_data","wb") as key_data:
#      18     key_data.write(key)
#      19
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\student\\Desktop\\key_data'

# %%
"""
復号版
"""
from cryptography.fernet import Fernet

#キーの読み込み
with open(r"C:\Users\user\test\test_key.key","rb") as test_key:
    key = test_key.read()
#暗号化したファイルの読み込み
with open(r"C:\Users\user\test\test.txt","rb") as file:
    encryp_data = file.read()

print("暗号化された情報: ",encryp_data)

#キーを使ってFernetオブジェクトを初期化
f = Fernet(key)
#データの復号化
decrypt_data = f.decrypt(encryp_data)

print("復号化した情報: ",decrypt_data.decode('utf-8'))

# %% [markdown]
# # 通信

# %% [markdown]
# # ファイル確認

# %%
"""
ファイルの簡易的な情報を手に入れるとこができる
ローカルにあることが必須
"""
import os
import datetime

filename = R"C:\Users\student\Desktop\test.txt"


print(os.path.getsize(filename)) # アイテムサイズ
print(os.path.getmtime(filename)) 
print(datetime.datetime.fromtimestamp(os.path.getmtime(filename))) # アイテム最終更新日
print(os.path.getctime(filename)) 
print(datetime.datetime.fromtimestamp(os.path.getctime(filename))) # アイテム作成日

print(os.stat(filename)) #アイテムのすべての情報を簡潔に表示
# Out:
# 0
# 1666769243.409438
# 2022-10-26 16:27:23.409438
# 1666769243.409438
# 2022-10-26 16:27:23.409438
# os.stat_result(st_mode=33206, st_ino=9288674231460001, st_dev=4201672466, st_nlink=1, st_uid=0, st_gid=0, st_size=0, st_atime=1666769243, st_mtime=1666769243, st_ctime=1666769243)
